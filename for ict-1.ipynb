# %% [markdown]
# ## Loan Deliqency

# %%
import numpy as np
import pandas as pd
import warnings; warnings.simplefilter('ignore')
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv("loan_dataset.csv")

# %%
train.head()
# Out:
#         loan_id source       financial_institution  interest_rate  \
# 0  268055008619      Z  Turner, Baldwin and Rhodes          4.250
# 1  672831657627      Y  Swanson, Newton and Miller          4.875
# 2  742515242108      Z              Thornton-Davis          3.250
# 3  601385667462      X                       OTHER          4.750
# 4  273870029961      X                       OTHER          4.750
#
#    unpaid_principal_bal  loan_term origination_date first_payment_date  \
# 0                214000        360       2012-03-01            05/2012
# 1                144000        360       2012-01-01            03/2012
# 2                366000        180       2012-01-01            03/2012
# 3                135000        360       2012-02-01            04/2012
# 4                124000        360       2012-02-01            04/2012
#
#    loan_to_value  number_of_borrowers  ...  m4  m5 m6  m7  m8  m9  m10  m11  \
# ...

# %%
train.source.value_counts()
# Out:
# X    63858
# Y    37554
# Z    14646
# Name: source, dtype: int64

# %%
train.groupby('source')['loan_term'].mean()
# Out:
# source
# X    281.947352
# Y    306.771103
# Z    300.182439
# Name: loan_term, dtype: float64

# %%
train.shape
# Out:
# (116058, 29)

# %%
y = pd.DataFrame(train['m13'])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116058 entries, 0 to 116057
# Data columns (total 29 columns):
# loan_id                     116058 non-null int64
# source                      116058 non-null object
# financial_institution       116058 non-null object
# interest_rate               116058 non-null float64
# unpaid_principal_bal        116058 non-null int64
# loan_term                   116058 non-null int64
# origination_date            116058 non-null object
# first_payment_date          116058 non-null object
# loan_to_value               116058 non-null int64
# number_of_borrowers         116058 non-null float64
# debt_to_income_ratio        116058 non-null float64
# borrower_credit_score       116058 non-null float64
# loan_purpose                116058 non-null object
# insurance_percent           116058 non-null float64
# co-borrower_credit_score    116058 non-null float64
# insurance_type              116058 non-null float64
# ...

# %%
train.isnull().sum()
# Out:
# loan_id                     0
# source                      0
# financial_institution       0
# interest_rate               0
# unpaid_principal_bal        0
# loan_term                   0
# origination_date            0
# first_payment_date          0
# loan_to_value               0
# number_of_borrowers         0
# debt_to_income_ratio        0
# borrower_credit_score       0
# loan_purpose                0
# insurance_percent           0
# co-borrower_credit_score    0
# insurance_type              0
# m1                          0
# m2                          0
# m3                          0
# m4                          0
# m5                          0
# m6                          0
# m7                          0
# m8                          0
# m9                          0
# m10                         0
# m11                         0
# m12                         0
# m13                         0
# dtype: int64

# %%
print(train.shape)
# Out:
# (116058, 29)

# %% [markdown]
# ## Labels percentage

# %%
train["m13"].value_counts(normalize=True)
# Out:
# 0    0.99452
# 1    0.00548
# Name: m13, dtype: float64

# %% [markdown]
# ### data types

# %%
train.dtypes
# Out:
# loan_id                       int64
# source                       object
# financial_institution        object
# interest_rate               float64
# unpaid_principal_bal          int64
# loan_term                     int64
# origination_date             object
# first_payment_date           object
# loan_to_value                 int64
# number_of_borrowers         float64
# debt_to_income_ratio        float64
# borrower_credit_score       float64
# loan_purpose                 object
# insurance_percent           float64
# co-borrower_credit_score    float64
# insurance_type              float64
# m1                            int64
# m2                            int64
# m3                            int64
# m4                            int64
# m5                            int64
# m6                            int64
# m7                            int64
# m8                            int64
# m9                            int64
# m10                           int64
# ...

# %%
train[['first_payment_date','origination_date']]
# Out:
#        first_payment_date origination_date
# 0                 05/2012       2012-03-01
# 1                 03/2012       2012-01-01
# 2                 03/2012       2012-01-01
# 3                 04/2012       2012-02-01
# 4                 04/2012       2012-02-01
# 5                 04/2012       2012-02-01
# 6                 04/2012       2012-02-01
# 7                 03/2012       2012-01-01
# 8                 05/2012       2012-03-01
# 9                 03/2012       2012-01-01
# 10                04/2012       2012-02-01
# 11                03/2012       2012-01-01
# 12                05/2012       2012-03-01
# 13                03/2012       2012-01-01
# 14                04/2012       2012-02-01
# 15                03/2012       2012-01-01
# 16                04/2012       2012-02-01
# 17                04/2012       2012-02-01
# 18                03/2012       2012-01-01
# 19                04/2012       2012-02-01
# 20                04/2012       2012-02-01
# ...

# %%
train.columns
# Out:
# Index(['loan_id', 'source', 'financial_institution', 'interest_rate',
#        'unpaid_principal_bal', 'loan_term', 'origination_date',
#        'first_payment_date', 'loan_to_value', 'number_of_borrowers',
#        'debt_to_income_ratio', 'borrower_credit_score', 'loan_purpose',
#        'insurance_percent', 'co-borrower_credit_score', 'insurance_type', 'm1',
#        'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'm10', 'm11', 'm12',
#        'm13'],
#       dtype='object')

# %%
X1 = train.drop(['loan_id', 'first_payment_date','origination_date','m13','insurance_percent','insurance_type'],axis=1)

# %%
train['financial_institution'].value_counts()
# Out:
# OTHER                          49699
# Browning-Hart                  31852
# Swanson, Newton and Miller      6874
# Edwards-Hoffman                 4857
# Martinez, Duffy and Bird        4715
# Miller, Mcclure and Allen       3158
# Nicholson Group                 2116
# Turner, Baldwin and Rhodes      1846
# Suarez Inc                      1790
# Cole, Brooks and Vincent        1642
# Richards-Walters                1459
# Taylor, Hunt and Rodriguez      1259
# Sanchez-Robinson                1193
# Sanchez, Hays and Wilkerson      853
# Romero, Woods and Johnson        750
# Thornton-Davis                   651
# Anderson-Taylor                  483
# Richardson Ltd                   473
# Chapman-Mcmahon                  388
# Name: financial_institution, dtype: int64

# %% [markdown]
# Here by label encoder I convert object values to numerical values

# %%
from sklearn.preprocessing import LabelEncoder
lm = LabelEncoder()
a  = ['financial_institution']
for i in np.arange(len(a)):
    X1[a[i]] = lm.fit_transform(X1[a[i]])

# %%
X1['source'].value_counts()
# Out:
# X    63858
# Y    37554
# Z    14646
# Name: source, dtype: int64

# %%
pd.get_dummies(X1['source'])
# Out:
#         X  Y  Z
# 0       0  0  1
# 1       0  1  0
# 2       0  0  1
# 3       1  0  0
# 4       1  0  0
# 5       0  1  0
# 6       1  0  0
# 7       0  1  0
# 8       1  0  0
# 9       1  0  0
# 10      1  0  0
# 11      1  0  0
# 12      1  0  0
# 13      1  0  0
# 14      0  1  0
# 15      1  0  0
# 16      0  1  0
# 17      0  1  0
# 18      0  1  0
# 19      0  1  0
# 20      1  0  0
# 21      0  1  0
# 22      1  0  0
# 23      1  0  0
# 24      1  0  0
# 25      1  0  0
# 26      0  1  0
# 27      1  0  0
# 28      1  0  0
# 29      0  1  0
# ...    .. .. ..
# 116028  0  1  0
# 116029  1  0  0
# 116030  0  0  1
# 116031  0  1  0
# 116032  0  1  0
# 116033  1  0  0
# 116034  1  0  0
# 116035  0  1  0
# 116036  0  1  0
# 116037  1  0  0
# 116038  1  0  0
# 116039  1  0  0
# 116040  0  0  1
# 116041  0  1  0
# 116042  1  0  0
# 116043  1  0  0
# 116044  1  0  0
# 116045  1  0  0
# 116046  1  0  0
# 116047  1  0  0
# 116048  1  0  0
# 116049  0  1  0
# 116050  1  0  0
# ...

# %%
pd.get_dummies(X1['loan_purpose'])
# Out:
#         A23  B12  C86
# 0         0    0    1
# 1         0    1    0
# 2         0    1    0
# 3         0    1    0
# 4         0    0    1
# 5         0    0    1
# 6         0    0    1
# 7         1    0    0
# 8         0    0    1
# 9         1    0    0
# 10        0    0    1
# 11        0    1    0
# 12        0    0    1
# 13        0    1    0
# 14        0    0    1
# 15        0    0    1
# 16        1    0    0
# 17        1    0    0
# 18        1    0    0
# 19        0    1    0
# 20        0    1    0
# 21        0    0    1
# 22        1    0    0
# 23        1    0    0
# 24        0    0    1
# 25        1    0    0
# 26        0    1    0
# 27        1    0    0
# 28        0    1    0
# 29        1    0    0
# ...     ...  ...  ...
# 116028    0    1    0
# 116029    1    0    0
# 116030    0    1    0
# 116031    0    0    1
# 116032    1    0    0
# 116033    0    1    0
# 116034    1    0    0
# 116035    0    0    1
# 116036    0    1    0
# ...

# %% [markdown]
# By one hot encoding I convert 'source','loan_purpose' into dummy variables

# %%
sourc = pd.get_dummies(X1['source'])
LoanP = pd.get_dummies(X1['loan_purpose'])

# %%
X1 = pd.concat([X1,LoanP],axis = 1)
X1 = X1.drop(['source','loan_purpose'],axis=1)

# %%
X1.head(10)
# Out:
#    financial_institution  interest_rate  unpaid_principal_bal  loan_term  \
# 0                     18          4.250                214000        360
# 1                     15          4.875                144000        360
# 2                     17          3.250                366000        180
# 3                      8          4.750                135000        360
# 4                      8          4.750                124000        360
# 5                      1          4.375                150000        360
# 6                      8          4.000                 59000        360
# 7                      1          4.500                319000        300
# 8                      1          4.000                520000        360
# 9                      8          4.000                214000        360
#
#    loan_to_value  number_of_borrowers  debt_to_income_ratio  \
# 0             95                  1.0                  22.0
# ...

# %%
X1.shape
# Out:
# (116058, 24)

# %%
y.shape
# Out:
# (116058, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.3, random_state=2)

# %%
X_train.shape
# Out:
# (81240, 24)

# %%
X_test.shape
# Out:
# (34818, 24)

# %%
y_train.shape
# Out:
# (81240, 1)

# %%
y_test.shape
# Out:
# (34818, 1)

# %%
rft=RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=3,max_features='auto',bootstrap=False,
                           verbose=2,warm_start=True,random_state=2)

# %%
rft.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 11 of 500
# building tree 12 of 500
# building tree 13 of 500
# building tree 14 of 500
# building tree 15 of 500
# building tree 16 of 500
# building tree 17 of 500
# building tree 18 of 500
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500
# building tree 23 of 500
# building tree 24 of 500
# building tree 25 of 500
# building tree 26 of 500
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500
# building tree 32 of 500
# ...

# %%
from sklearn.metrics import f1_score,confusion_matrix

# %%
y_pred=rft.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.9s finished

# %%
y_pred.shape
# Out:
# (34818,)

# %%
print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# 0.36000000000000004
# array([[34613,     6],
#        [  154,    45]])

# %%
rft=RandomForestClassifier(n_estimators=1000,criterion='entropy',max_depth=3,max_features='auto',bootstrap=False,
                           verbose=2,warm_start=True,random_state=2)
rft.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# building tree 1 of 1000
# building tree 2 of 1000
# building tree 3 of 1000
# building tree 4 of 1000
# building tree 5 of 1000
# building tree 6 of 1000
# building tree 7 of 1000
# building tree 8 of 1000
# building tree 9 of 1000
# building tree 10 of 1000
# building tree 11 of 1000
# building tree 12 of 1000
# building tree 13 of 1000
# building tree 14 of 1000
# building tree 15 of 1000
# building tree 16 of 1000
# building tree 17 of 1000
# building tree 18 of 1000
# building tree 19 of 1000
# building tree 20 of 1000
# building tree 21 of 1000
# building tree 22 of 1000
# building tree 23 of 1000
# building tree 24 of 1000
# building tree 25 of 1000
# building tree 26 of 1000
# building tree 27 of 1000
# building tree 28 of 1000
# building tree 29 of 1000
# building tree 30 of 1000
# building tree 31 of 1000
# ...

# %%
y_pred=rft.predict(X_test)

print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# 0.35856573705179284
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    1.6s finished
# array([[34612,     7],
#        [  154,    45]])

# %%
rft=RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=10,max_features='auto',bootstrap=False,
                           verbose=2,warm_start=True,random_state=2)
rft.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 11 of 500
# building tree 12 of 500
# building tree 13 of 500
# building tree 14 of 500
# building tree 15 of 500
# building tree 16 of 500
# building tree 17 of 500
# building tree 18 of 500
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500
# building tree 23 of 500
# building tree 24 of 500
# building tree 25 of 500
# building tree 26 of 500
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500
# building tree 32 of 500
# ...

# %%
y_pred=rft.predict(X_test)

print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# 0.4827586206896552
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.6s finished
# array([[34598,    21],
#        [  129,    70]])

# %%
rft=RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=10,max_features='auto',bootstrap=False,
                           verbose=2,warm_start=True,random_state=2,min_samples_split= 5)
rft.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 11 of 500
# building tree 12 of 500
# building tree 13 of 500
# building tree 14 of 500
# building tree 15 of 500
# building tree 16 of 500
# building tree 17 of 500
# building tree 18 of 500
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500
# building tree 23 of 500
# building tree 24 of 500
# building tree 25 of 500
# building tree 26 of 500
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500
# building tree 32 of 500
# ...

# %%
y_pred=rft.predict(X_test)

print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# 0.4758620689655172
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.6s finished
# array([[34597,    22],
#        [  130,    69]])

# %%
rft=RandomForestClassifier(n_estimators=500,criterion='entropy',max_depth=10,max_features='auto',bootstrap=False,
                           verbose=2,warm_start=True,random_state=2,min_samples_split= 4)
rft.fit(X_train,y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# building tree 1 of 500
# building tree 2 of 500
# building tree 3 of 500
# building tree 4 of 500
# building tree 5 of 500
# building tree 6 of 500
# building tree 7 of 500
# building tree 8 of 500
# building tree 9 of 500
# building tree 10 of 500
# building tree 11 of 500
# building tree 12 of 500
# building tree 13 of 500
# building tree 14 of 500
# building tree 15 of 500
# building tree 16 of 500
# building tree 17 of 500
# building tree 18 of 500
# building tree 19 of 500
# building tree 20 of 500
# building tree 21 of 500
# building tree 22 of 500
# building tree 23 of 500
# building tree 24 of 500
# building tree 25 of 500
# building tree 26 of 500
# building tree 27 of 500
# building tree 28 of 500
# building tree 29 of 500
# building tree 30 of 500
# building tree 31 of 500
# building tree 32 of 500
# ...

# %%
threshold = 0.23
y_pred_prob = rft.predict_proba(X_test)[:,1]
y_pred = (y_pred_prob > threshold).astype(int)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.6s finished

# %%
print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# 0.5478723404255319
# array([[34545,    74],
#        [   96,   103]])

# %%
X1.describe().T
# Out:
#                              count           mean            std       min  \
# financial_institution     116058.0       6.517207       4.450898      0.00
# interest_rate             116058.0       3.868961       0.461020      2.25
# unpaid_principal_bal      116058.0  208226.223095  114685.099114  11000.00
# loan_term                 116058.0     292.280997      89.762415     60.00
# loan_to_value             116058.0      67.431939      17.291719      6.00
# number_of_borrowers       116058.0       1.593186       0.491242      1.00
# debt_to_income_ratio      116058.0      30.742293       9.730798      1.00
# borrower_credit_score     116058.0     769.926778      42.210706      0.00
# co-borrower_credit_score  116058.0     459.611565     381.946926      0.00
# m1                        116058.0       0.003197       0.063354      0.00
# m2                        116058.0       0.002059       0.051391      0.00
# ...

# %%
threshold = 0.23
y_pred_prob = rft.predict_proba(X_test)[:,1]
y_pred = (y_pred_prob > threshold).astype(int)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    1.5s finished

# %%
print(f1_score(y_test,y_pred))

confusion_matrix(y_test,y_pred)
# Out:
# 0.5478723404255319
# array([[34545,    74],
#        [   96,   103]])

# %%
pd.Series(rft.feature_importances_,index=X1.columns).sort_values(ascending=False)
# Out:
# m12                         0.270514
# m11                         0.162229
# m9                          0.101586
# m10                         0.089772
# borrower_credit_score       0.071167
# m8                          0.045890
# m7                          0.035822
# co-borrower_credit_score    0.030267
# interest_rate               0.025426
# m5                          0.023879
# debt_to_income_ratio        0.023414
# unpaid_principal_bal        0.020410
# m4                          0.020306
# loan_to_value               0.017419
# m6                          0.016744
# financial_institution       0.009629
# m1                          0.006711
# loan_term                   0.006018
# number_of_borrowers         0.005092
# m3                          0.004263
# m2                          0.004004
# C86                         0.003374
# A23                         0.003197
# B12                         0.002868
# dtype: float64

# %% [markdown]
# I hyper tuned my random forest classifier by varying depth between [6,15] and min sample split between[2,5]. I used criterion as "Entropy" because entropy has an edge in some data cases involving a high imbalance.
# I have given class weight { 0:0.8, 1:1 } to minimize 'class1' error which means "It is ok that If I don't give loan to 2-3 good guys but I don't want to give loan to those people who can be loan defaulters".

# %%
model = RandomForestClassifier(random_state=42,max_depth= 10 ,min_samples_split= 5 ,n_estimators= 500,n_jobs=-1, min_samples_leaf=2,  criterion='entropy',class_weight= {0: 0.8, 1:1})
model.fit(X,y)
y_pred = model.predict(Test)

# %%
pd.DataFrame({'loan_id':ID,'m13':  y_pred}).set_index('loan_id').to_csv('submission.csv')
pd.Series(model.feature_importances_,index=X1.columns).sort_values(ascending=False)
# Out:
# m12                         0.222896
# m11                         0.134618
# m10                         0.086091
# co-borrower_credit_score    0.066642
# borrower_credit_score       0.062377
# number_of_borrowers         0.060914
# A23                         0.057362
# m9                          0.056508
# m8                          0.042183
# m7                          0.032203
# B12                         0.031399
# C86                         0.027774
# interest_rate               0.022741
# financial_institution       0.020052
# loan_term                   0.018583
# m5                          0.017432
# m6                          0.014583
# m4                          0.006696
# unpaid_principal_bal        0.006302
# debt_to_income_ratio        0.004128
# loan_to_value               0.004090
# m1                          0.001848
# m3                          0.001389
# m2                          0.001188
# dtype: float64

# %%
sum(y_pred)
# Out:
# 153
